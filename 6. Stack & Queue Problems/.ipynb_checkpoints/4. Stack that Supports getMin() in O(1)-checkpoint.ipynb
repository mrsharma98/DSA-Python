# %% [raw]
# Design a data structure which support push()/pop()/findminimum() operation in O(1) time

# %%
for getMin:-
arr = [3,5,2,1,1,-1], stack = [], formula:- 2*element-minEle => to get the element to be stored in stack, minEle=-99999

insert 3 => stack = [3], minElement = 3
insert 5 => stack =[3,5], minElement = 3
insert 2 => smaller than minEle(3) => 2*(2)-(3)=1 => stack = [3,5,1], minEle=2
insert 1 => smaller than minEle(2) => 2*(1)-(2)=0 => stack=[3,5,1,0], minEle=1
insert 1 => Also if equal to minEle store the actual number.
insert -1 => minElm = -1, stack=[3,5,1,0,-3]

... so on

For updating minEle after pop()
formula:- 2*minEle - eleOnStack => to get the next minElment
pop() i.e pop(-3) => 2*(-1)-(-3)=1, minElm=1
pop() i.e. pop(1) => 2*(1)-(1), minEle=1
pop() i.e. pop(0) => 2*(1)-0, minEle=2
... so on

# %%
class MinStack:

    def __init__(self):
        self.minElement = 0
        self.length = 0
        self.stack = []
        

    def push(self, val: int) -> None:
        if self.length==0:
            self.stack.append(val)
            self.minElement = val
        else:
            if (val<self.minElement):
                ele = 2*(val)-self.minElement
                self.stack.append(ele)
                self.minElement = val
            else:
                self.stack.append(val)
                
        self.length += 1
        return
        

    def pop(self) -> None:
        if self.length==0:
            return
         
        top = self.stack.pop()
        if top<self.minElement:
            self.minElement = 2*(self.minElement)-top
        return 

    def getMin(self) -> int:
        if self.length==0:
            return
        return self.minElement


# Your MinStack object will be instantiated and called as such:
# obj = MinStack()
# obj.push(val)
# obj.pop()
# param_3 = obj.top()
# param_4 = obj.getMin()

# %%
class MinStack:

    def __init__(self):
        self.minElement = 0
        self.length = 0
        self.stack = []
        self.minStack = []
        

    def push(self, val: int) -> None:
        if self.length==0:
            self.stack.append(val)
            self.minStack = [0]
        else:
            self.stack.append(val)
            if (val<self.stack[self.minStack[-1]]):
                self.minStack.append(self.length)
                
        self.length += 1
        return
        

    def pop(self) -> None:
        if self.length==0:
            return
         
        top = self.stack.pop()
        if self.length-1==self.minStack[-1]:
            self.minStack.pop()
        
        self.length -= 1
        
        return 

    def top(self) -> int:
        if self.length==0:
            return
        return self.stack[-1]

    def getMin(self) -> int:
        if self.length==0:
            return
        return self.stack[self.minStack[-1]]


# Your MinStack object will be instantiated and called as such:
# obj = MinStack()
# obj.push(val)
# obj.pop()
# param_3 = obj.top()
# param_4 = obj.getMin()
