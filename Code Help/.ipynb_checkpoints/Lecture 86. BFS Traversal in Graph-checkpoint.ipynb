# %% [raw]
# we need DS
# 1. A map for tracking all the node if visited or not
#     map<node, bool>
# 2. A Queue to iterate the neighbour of the node
#
# Take a node print it and put into queue, print the neighbour and put it to the Queue
#
# TC and SC:- O(n+e)

# %%
def prepareAdjList(adjList, edges):
    for i in range(len(edges)):
        u = edges[i][0]
        v = edges[i][1]
        
        adjList.setdefault(u, []).append(v)
        adjList.setdefault(v, []).append(u)


def solve(adjList, visited, ans, node):
    q = []
    q.append(node)
    visited[node] = 1
    
    while (len(q)>0):
        frontNode = q[0]
        q.pop(0)
        
        # store fronNode into ans
        ans.append(frontNode)
        
        # traverse all neighbours of frontNode
        for i in adj[frontNode]:
            if (visited.get(i)):
                q.apend(i)
                visited[i] = 1
            


def BFS(vertex, edges):
    # unordered map <int, list<int>>
    adjList = {}
    ans = []
    
    # unordered map <int, bool>
    visited = {}
    
    prepareAdjList(adjList, edges)
    
    # traverse all components of a graph
    for i in range(len(vertex)):
        if not visited.get(i)
            solve(adjList, visited, ans, i)
    
    return ans

# %%
from collections import defaultdict

def prepareAdjList(adjList, edges):
    for i in range(len(edges)):
        u = edges[i][0]
        v = edges[i][1]
        adjList[u].append(v)
        adjList[v].append(u)
        

def solve(adjList, visisted, ans, node):
    visited[i] = True
    q = deque()
    q.append(node)
    
    while len(q)>0:
        frontNode = q.popleft()
        ans.append(frontNode)
        
        for i in adjList[frontNode]:
            if not visited.get(i):
                visited[i] = True
                q.append(i)
        


def bfs(vertex, edges):
    adjList = defaultdict(list)
    ans = []
    prepareAdjList(adjList, edges)
    
    visited = {}
    
    # traverse all component and nodes
    for i in range(vertex):
        if not visited.get(i):
            solve(adjList, visited, ans, i)
